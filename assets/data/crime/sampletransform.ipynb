# %%
import pandas as pd
import datetime
# Out:
# <function datetime.strptime>

# %%
too_much = pd.read_csv("LA-Crime_Data_from_2010_to_2019.csv")
too_much.head()
# Out:
# C:\Users\maria\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11034701    JA366925  01/01/2001 11:00:00 AM       016XX E 86TH PL  1153
# 1  11227287    JB147188  10/08/2017 03:00:00 AM    092XX S RACINE AVE  0281
# 2  11227583    JB147595  03/28/2017 02:00:00 PM       026XX W 79TH ST  0620
# 3  11227293    JB147230  09/09/2017 08:17:00 PM  060XX S EBERHART AVE  0810
# 4  11227634    JB147599  08/26/2017 10:00:00 AM   001XX W RANDOLPH ST  0281
#
#           Primary Type                          Description  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
# 2             BURGLARY                       UNLAWFUL ENTRY
# ...

# %%
too_much = too_much.rename(columns = {'DATE OCC':'date'})
too_much['date'] = pd.to_datetime(too_much['date'])
filtered=too_much[(['date'] > '2013-01-01') & (df['date'] < '2013-02-01')]
filtered.head()
# Out:
#           ID Case Number                date                    Block  IUCR  \
# 44  11223717    JB141803 2018-02-04 15:25:00  044XX W WASHINGTON BLVD  1153
# 55  11243511    JB168893 2018-02-20 16:21:00     005XX W ARLINGTON PL  0820
# 65  11223707    JB141873 2018-02-05 00:00:00      061XX N KENMORE AVE  2820
# 67  11228287    JB148482 2018-01-03 15:45:00            0000X W C1 ST  0810
# 68  11632509    JC196665 2018-11-26 01:00:00     029XX S MICHIGAN AVE  1150
#
#           Primary Type                          Description  \
# 44  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 55               THEFT                       $500 AND UNDER
# 65       OTHER OFFENSE                     TELEPHONE THREAT
# 67               THEFT                            OVER $500
# 68  DECEPTIVE PRACTICE                    CREDIT CARD FRAUD
#
#                               Location Description  Arrest  Domestic  ...  \
# ...

# %%
filtered.to_csv("chicago_2018_2020.csv")
